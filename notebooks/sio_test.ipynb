# %% [markdown]
# # Overpass: Satellite Time-Series Extraction
# ### Station: Scripps Institution of Oceanography (SIO)
#
# This notebook demonstrates the use of the `overpass` package to extract hyperspectral data from the NASA PACE OCI sensor. We will establish a historical time-series for a specific GPS coordinate, comparing standard Remote Sensing Reflectance ($R_{rs}$) with Rayleigh-Corrected Reflectance ($R_{rc}$).
#
# ## Objectives
# 1. **Authentication**: Connect to NASA Earthdata via `earthaccess`.
# 2. **Extraction**: Utilize `OverpassExtractor` to perform batch-processing of OCI Level 2 granules.
# 3. **Resilience**: Demonstrate the checkpoint and resume logic for long-running extractions.
# 4. **Validation**: Apply coastal-optimized flag filtering to $R_{rc}$ spectra to handle turbid water conditions near the pier.
#
# ## Station Metadata
# - **Location**: Scripps Pier, La Jolla, CA
# - **Coordinates**: 32.867°N, 117.257°W
# - **Instrument**: PACE Ocean Color Instrument (OCI)
# - **Temporal Range**: April 2024 to Present
#
# ---

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import earthaccess
import xarray as xr
import matplotlib.pyplot as pp
from over
